# %%
import json
import datetime
fd=open("IMS_records.json",'r')
a=fd.read()
fd.close()

# %%
a

# %%
record=json.loads(a)

# %%
record
# Out:
# {'1001': {'brand': 'Lays',
#   'cat': 'Food-item',
#   'd': '30-03-2023',
#   'name': 'Potato Chhips',
#   'pr': 17,
#   'qu': 45},
#  '1002': {'brand': 'Lotte',
#   'cat': 'food',
#   'date': '20-09-2022',
#   'name': 'Choco-Pie',
#   'pr': 25,
#   'qu': 25},
#  '1003': {'brand': 'Dairy',
#   'cat': 'food',
#   'date': '20-09-2021',
#   'name': 'Milk',
#   'pr': 60,
#   'qu': 15},
#  '1004': {'brand': 'gemini',
#   'cat': 'food',
#   'date': '20-12-2022',
#   'name': 'cookingoil',
#   'pr': 80,
#   'qu': 15},
#  '1005': {'brand': 'Lays',
#   'cat': 'food',
#   'date': '20-12-2021',
#   'name': 'Chips',
#   'pr': 20,
#   'qu': 20},
#  '1006': {'brand': 'MotherEarth',
#   'cat': 'food',
#   'date': '12-09-2021',
#   'name': 'Bread',
#   'pr': 25,
#   'qu': 10},
#  '1007': {'brand': 'Kissan',
#   'cat': 'food',
#   'date': '20-12-2022',
#   'name': 'Fruit-Jam',
#   'pr': 60,
#   'qu': 20},
#  '1008': {'brand': 'Maggie',
#   'cat': 'food',
#   'date': '20-10-2022',
#   'name': 'Noodles',
#   'pr': 20,
#   'qu': 20},
#  '1009': {'brand': 'Perk',
#   'cat': 'food',
#   'date': '12-12-2021',
#   'name': '5 Star',
#   'pr': 20,
#   'qu': 10},
#  '1010': {'brand': 'Amul',
#   'cat': 'food',
#   'date': '24-08-2022',
#   'name': 'Bytter',
#   'pr': 50,
#   'qu': 25},
#  '1011': {'brand': 'Jimmy',
#   'cat': 'food',
#   'date': '12-09-2022',
#   'name': 'Tomato-Ketchup',
#   'pr': 35,
#   'qu': 25},
#  '1012': {'brand': 'Haldiram',
#   'cat': 'food',
#   'date': '15-07-2023',
#   'name': 'Sonpapdi',
#   'pr': 150,
#   'qu': 20},
#  '1013': {'brand': 'Almond',
#   'cat': 'Cosmetic',
#   'date': '28-02-2023',
#   'name': 'Hiar-oil',
#   'pr': 45,
#   'qu': 25},
#  '1014': {'brand': 'Nykaa',
#   'cat': 'Cosmetic',
#   'date': '14-08-2024',
#   'name': 'Nailpolish',
#   'pr': 50,
#   'qu': 25},
#  '1015': {'brand': 'MamaEarth',
#   'cat': 'Cosmetic',
#   'date': '16-07-2023',
#   'name': 'Hair Serum',
#   'pr': 80,
#   'qu': 10},
#  '1016': {'brand': 'Himalaya',
#   'cat': 'Cosmetic',
#   'date': '17-06-2023',
#   'name': 'Facewash',
#   'pr': 45,
#   'qu': 25},
#  '1017': {'brand': 'Lifeboy',
#   'cat': 'Medicinal',
#   'date': '16-05-2022',
#   'name': 'Hand-Sanitizer',
#   'pr': 35,
#   'qu': 35},
#  '1018': {'brand': 'Dettol',
#   'cat': 'Medicinal',
#   'date': '15-02-2023',
#   'name': 'Floor-Cleaner',
#   'pr': 80,
#   'qu': 20},
#  '1019': {'brand': 'LUX',
#   'cat': 'Medicinal',
#   'date': '16-09-2022',
#   'name': 'Bodywash',
#   'pr': 60,
#   'qu': 40},
#  '1020': {'brand': 'Cornato',
#   'cat': 'food',
#   'date': '19-10-2021',
#   'name': 'Ice-Cream',
#   'pr': 100,
#   'qu': 45},
#  '1021': {'brand': 'Govid',
#   'cat': 'food',
#   'date': '10-09-2021',
#   'name': 'Panner',
#   'pr': 60,
#   'qu': 5},
#  '1022': {'brand': 'Milkyway',
#   'cat': 'food',
#   'date': '15-10-2021',
#   'name': 'Crud',
#   'pr': 50,
#   'qu': 15},
#  '1023': {'brand': 'Milky',
#   'cat': 'food',
#   'date': '13-10-2021',
#   'name': 'ilkyBar',
#   'pr': 25,
#   'qu': 25},
#  '1024': {'brand': 'out-all',
#   'cat': 'medicinal',
#   'date': '10-02-2023',
#   'name': 'All-Out',
#   'pr': 40,
#   'qu': 20},
#  '1025': {'brand': 'Apollo',
#   'cat': 'medicinal',
#   'date': '23-12-2024',
#   'name': 'Facemask',
#   'pr': 60,
#   'qu': 25},
#  '1026': {'brand': 'Bharat',
#   'cat': 'food',
#   'date': '12-12-2021',
#   'name': 'Whaet',
#   'pr': 30,
#   'qu': 45},
#  '1027': {'brand': 'Apna',
#   'cat': 'food',
#   'date': '10-10-2022',
#   'name': 'Rice',
#   'pr': 45,
#   'qu': 35},
#  '1028': {'brand': 'Ashirwad',
#   'cat': 'food',
#   'date': '13-03-2022',
#   'name': 'Bajra',
#   'pr': 35,
#   'qu': 45},
#  '1029': {'brand': 'khara',
#   'cat': 'food',
#   'date': '14-05-2022',
#   'name': 'sugar',
#   'pr': 45,
#   'qu': 35},
#  '1030': {'brand': 'Vim',
#   'cat': 'Cosmetic',
#   'date': '19-11-2022',
#   'name': 'Dishwashing soap',
#   'pr': 15,
#   'qu': 20},
#  '1031': {'brand': 'HenzBenz',
#   'cat': 'food',
#   'date': '13-04-2022',
#   'name': 'Canned Beans',
#   'pr': 100,
#   'qu': 25},
#  '1032': {'brand': 'Aquaa',
#   'cat': 'food',
#   'date': '12-02-2022',
#   'name': 'Water',
#   'pr': 20,
#   'qu': 20}}

# %%
id=str(input("Enter Product Id:"))
name=str(input("Enter the product name:"))
cat=str(input("Enter Product category:"))
pr=int(input("Enter the prize of product:"))
qu=int(input("Enter the Quantity of Product:"))
brand=str(input("Enter the brand of Product:"))
date=input("Enter the Validity date:")
print("New Product added!!!")
record[id]={'name':name,'brand':brand,'pr':pr,"qu":qu,'date':date,'cat':cat}

js=json.dumps(record)

fd=open("IMS_records.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter Product Id:1033
# Enter the product name:Salt
# Enter Product category:Food
# Enter the prize of product:20
# Enter the Quantity of Product:100
# Enter the brand of Product:TATA
# Enter the Validity date:12-12-2021
# New Product added!!!

# %%
record
# Out:
# {'1001': {'brand': 'Lays',
#   'cat': 'Food-item',
#   'd': '30-03-2023',
#   'name': 'Potato Chhips',
#   'pr': 17,
#   'qu': 45},
#  '1002': {'brand': 'Lotte',
#   'cat': 'food',
#   'date': '20-09-2022',
#   'name': 'Choco-Pie',
#   'pr': 25,
#   'qu': 25},
#  '1003': {'brand': 'Dairy',
#   'cat': 'food',
#   'date': '20-09-2021',
#   'name': 'Milk',
#   'pr': 60,
#   'qu': 15},
#  '1004': {'brand': 'gemini',
#   'cat': 'food',
#   'date': '20-12-2022',
#   'name': 'cookingoil',
#   'pr': 80,
#   'qu': 15},
#  '1005': {'brand': 'Lays',
#   'cat': 'food',
#   'date': '20-12-2021',
#   'name': 'Chips',
#   'pr': 20,
#   'qu': 20},
#  '1006': {'brand': 'MotherEarth',
#   'cat': 'food',
#   'date': '12-09-2021',
#   'name': 'Bread',
#   'pr': 25,
#   'qu': 10},
#  '1007': {'brand': 'Kissan',
#   'cat': 'food',
#   'date': '20-12-2022',
#   'name': 'Fruit-Jam',
#   'pr': 60,
#   'qu': 20},
#  '1008': {'brand': 'Maggie',
#   'cat': 'food',
#   'date': '20-10-2022',
#   'name': 'Noodles',
#   'pr': 20,
#   'qu': 20},
#  '1009': {'brand': 'Perk',
#   'cat': 'food',
#   'date': '12-12-2021',
#   'name': '5 Star',
#   'pr': 20,
#   'qu': 10},
#  '1010': {'brand': 'Amul',
#   'cat': 'food',
#   'date': '24-08-2022',
#   'name': 'Bytter',
#   'pr': 50,
#   'qu': 25},
#  '1011': {'brand': 'Jimmy',
#   'cat': 'food',
#   'date': '12-09-2022',
#   'name': 'Tomato-Ketchup',
#   'pr': 35,
#   'qu': 25},
#  '1012': {'brand': 'Haldiram',
#   'cat': 'food',
#   'date': '15-07-2023',
#   'name': 'Sonpapdi',
#   'pr': 150,
#   'qu': 20},
#  '1013': {'brand': 'Almond',
#   'cat': 'Cosmetic',
#   'date': '28-02-2023',
#   'name': 'Hiar-oil',
#   'pr': 45,
#   'qu': 25},
#  '1014': {'brand': 'Nykaa',
#   'cat': 'Cosmetic',
#   'date': '14-08-2024',
#   'name': 'Nailpolish',
#   'pr': 50,
#   'qu': 25},
#  '1015': {'brand': 'MamaEarth',
#   'cat': 'Cosmetic',
#   'date': '16-07-2023',
#   'name': 'Hair Serum',
#   'pr': 80,
#   'qu': 10},
#  '1016': {'brand': 'Himalaya',
#   'cat': 'Cosmetic',
#   'date': '17-06-2023',
#   'name': 'Facewash',
#   'pr': 45,
#   'qu': 25},
#  '1017': {'brand': 'Lifeboy',
#   'cat': 'Medicinal',
#   'date': '16-05-2022',
#   'name': 'Hand-Sanitizer',
#   'pr': 35,
#   'qu': 35},
#  '1018': {'brand': 'Dettol',
#   'cat': 'Medicinal',
#   'date': '15-02-2023',
#   'name': 'Floor-Cleaner',
#   'pr': 80,
#   'qu': 20},
#  '1019': {'brand': 'LUX',
#   'cat': 'Medicinal',
#   'date': '16-09-2022',
#   'name': 'Bodywash',
#   'pr': 60,
#   'qu': 40},
#  '1020': {'brand': 'Cornato',
#   'cat': 'food',
#   'date': '19-10-2021',
#   'name': 'Ice-Cream',
#   'pr': 100,
#   'qu': 45},
#  '1021': {'brand': 'Govid',
#   'cat': 'food',
#   'date': '10-09-2021',
#   'name': 'Panner',
#   'pr': 60,
#   'qu': 5},
#  '1022': {'brand': 'Milkyway',
#   'cat': 'food',
#   'date': '15-10-2021',
#   'name': 'Crud',
#   'pr': 50,
#   'qu': 15},
#  '1023': {'brand': 'Milky',
#   'cat': 'food',
#   'date': '13-10-2021',
#   'name': 'ilkyBar',
#   'pr': 25,
#   'qu': 25},
#  '1024': {'brand': 'out-all',
#   'cat': 'medicinal',
#   'date': '10-02-2023',
#   'name': 'All-Out',
#   'pr': 40,
#   'qu': 20},
#  '1025': {'brand': 'Apollo',
#   'cat': 'medicinal',
#   'date': '23-12-2024',
#   'name': 'Facemask',
#   'pr': 60,
#   'qu': 25},
#  '1026': {'brand': 'Bharat',
#   'cat': 'food',
#   'date': '12-12-2021',
#   'name': 'Whaet',
#   'pr': 30,
#   'qu': 45},
#  '1027': {'brand': 'Apna',
#   'cat': 'food',
#   'date': '10-10-2022',
#   'name': 'Rice',
#   'pr': 45,
#   'qu': 35},
#  '1028': {'brand': 'Ashirwad',
#   'cat': 'food',
#   'date': '13-03-2022',
#   'name': 'Bajra',
#   'pr': 35,
#   'qu': 45},
#  '1029': {'brand': 'khara',
#   'cat': 'food',
#   'date': '14-05-2022',
#   'name': 'sugar',
#   'pr': 45,
#   'qu': 35},
#  '1030': {'brand': 'Vim',
#   'cat': 'Cosmetic',
#   'date': '19-11-2022',
#   'name': 'Dishwashing soap',
#   'pr': 15,
#   'qu': 20},
#  '1031': {'brand': 'HenzBenz',
#   'cat': 'food',
#   'date': '13-04-2022',
#   'name': 'Canned Beans',
#   'pr': 100,
#   'qu': 25},
#  '1032': {'brand': 'Aquaa',
#   'cat': 'food',
#   'date': '12-02-2022',
#   'name': 'Water',
#   'pr': 20,
#   'qu': 20},
#  '1033': {'brand': 'TATA',
#   'cat': 'Food',
#   'date': '12-12-2021',
#   'name': 'Salt',
#   'pr': 20,
#   'qu': 100}}

# %%
  js=json.dumps(record)

# %%
fd=open("IMS_records.json",'w')
fd.write(js)
fd.close()

# %%
js
# Out:
# '{"1001": {"name": "Potato Chhips", "brand": "Lays", "qu": 45, "pr": 17, "d": "30-03-2023", "cat": "Food-item"}, "1002": {"name": "Choco-Pie", "brand": "Lotte", "pr": 25, "qu": 25, "date": "20-09-2022", "cat": "food"}, "1003": {"name": "Milk", "brand": "Dairy", "pr": 60, "qu": 15, "date": "20-09-2021", "cat": "food"}, "1004": {"name": "cookingoil", "brand": "gemini", "pr": 80, "qu": 15, "date": "20-12-2022", "cat": "food"}, "1005": {"name": "Chips", "brand": "Lays", "pr": 20, "qu": 20, "date": "20-12-2021", "cat": "food"}, "1006": {"name": "Bread", "brand": "MotherEarth", "pr": 25, "qu": 10, "date": "12-09-2021", "cat": "food"}, "1007": {"name": "Fruit-Jam", "brand": "Kissan", "pr": 60, "qu": 20, "date": "20-12-2022", "cat": "food"}, "1008": {"name": "Noodles", "brand": "Maggie", "pr": 20, "qu": 20, "date": "20-10-2022", "cat": "food"}, "1009": {"name": "5 Star", "brand": "Perk", "pr": 20, "qu": 10, "date": "12-12-2021", "cat": "food"}, "1010": {"name": "Bytter", "brand": "Amul", "pr": 50, "qu": 25, "date": "24-08-2022", "cat": "food"}, "1011": {"name": "Tomato-Ketchup", "brand": "Jimmy", "pr": 35, "qu": 25, "date": "12-09-2022", "cat": "food"}, "1012": {"name": "Sonpapdi", "brand": "Haldiram", "pr": 150, "qu": 20, "date": "15-07-2023", "cat": "food"}, "1013": {"name": "Hiar-oil", "brand": "Almond", "pr": 45, "qu": 25, "date": "28-02-2023", "cat": "Cosmetic"}, "1014": {"name": "Nailpolish", "brand": "Nykaa", "pr": 50, "qu": 25, "date": "14-08-2024", "cat": "Cosmetic"}, "1015": {"name": "Hair Serum", "brand": "MamaEarth", "pr": 80, "qu": 10, "date": "16-07-2023", "cat": "Cosmetic"}, "1016": {"name": "Facewash", "brand": "Himalaya", "pr": 45, "qu": 25, "date": "17-06-2023", "cat": "Cosmetic"}, "1017": {"name": "Hand-Sanitizer", "brand": "Lifeboy", "pr": 35, "qu": 35, "date": "16-05-2022", "cat": "Medicinal"}, "1018": {"name": "Floor-Cleaner", "brand": "Dettol", "pr": 80, "qu": 20, "date": "15-02-2023", "cat": "Medicinal"}, "1019": {"name": "Bodywash", "brand": "LUX", "pr": 60, "qu": 40, "date": "16-09-2022", "cat": "Medicinal"}, "1020": {"name": "Ice-Cream", "brand": "Cornato", "pr": 100, "qu": 45, "date": "19-10-2021", "cat": "food"}, "1021": {"name": "Panner", "brand": "Govid", "pr": 60, "qu": 5, "date": "10-09-2021", "cat": "food"}, "1022": {"name": "Crud", "brand": "Milkyway", "pr": 50, "qu": 15, "date": "15-10-2021", "cat": "food"}, "1023": {"name": "ilkyBar", "brand": "Milky", "pr": 25, "qu": 25, "date": "13-10-2021", "cat": "food"}, "1024": {"name": "All-Out", "brand": "out-all", "pr": 40, "qu": 20, "date": "10-02-2023", "cat": "medicinal"}, "1025": {"name": "Facemask", "brand": "Apollo", "pr": 60, "qu": 25, "date": "23-12-2024", "cat": "medicinal"}, "1026": {"name": "Whaet", "brand": "Bharat", "pr": 30, "qu": 45, "date": "12-12-2021", "cat": "food"}, "1027": {"name": "Rice", "brand": "Apna", "pr": 45, "qu": 35, "date": "10-10-2022", "cat": "food"}, "1028": {"name": "Bajra", "brand": "Ashirwad", "pr": 35, "qu": 45, "date": "13-03-2022", "cat": "food"}, "1029": {"name": "sugar", "brand": "khara", "pr": 45, "qu": 35, "date": "14-05-2022", "cat": "food"}, "1030": {"name": "Dishwashing soap", "brand": "Vim", "pr": 15, "qu": 20, "date": "19-11-2022", "cat": "Cosmetic"}, "1031": {"name": "Canned Beans", "brand": "HenzBenz", "pr": 100, "qu": 25, "date": "13-04-2022", "cat": "food"}, "1032": {"name": "Water", "brand": "Aquaa", "pr": 20, "qu": 20, "date": "12-02-2022", "cat": "food"}, "1033": {"name": "Salt", "brand": "TATA", "pr": 20, "qu": 100, "date": "12-12-2021", "cat": "Food"}}'
